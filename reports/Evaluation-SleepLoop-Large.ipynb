# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import os
import sys
import matplotlib.pyplot as plt
root_dir = os.path.abspath(os.path.join(os.path.dirname('__file__'), '..'))
sys.path.insert(0, root_dir)
from sleeplearning.lib.evaluation import Evaluation

# %% [markdown]
# ## Sleep Loop Data (Crossvalidation on old data)

# %%
path = 'results/caro/cv'
e = Evaluation(path)
# Out:
# model attention
# config: all
# runs: cv_test2.csv

# %%
e.cm()

# %%
e.table()

# %% [markdown]
# ## Sleep Loop Data (Crossvalidation on all data)

# %%
path = 'results/caro_new/cv'
e = Evaluation(path)
# Out:
# model attention
# config: all
# runs: cv_test2.csv

# %%
e.cm()

# %% [markdown]
# This cell displays the confusion matrix on the evaluation data.

# %%
e.table()

# %%
WESA_S005_N3S_MLready.mat       Total: 1435
W:0.08, N1:0.21, N2:0.43, N3:0.01, N4:0.00, R:0.27, A:0.00
WESA_S016_N7S_MLready.mat       Total: 1467
W:0.06, N1:0.07, N2:0.61, N3:0.14, N4:0.00, R:0.13, A:0.00
WESA_S006_N11S_MLready.mat      Total: 1557
W:0.09, N1:0.07, N2:0.55, N3:0.05, N4:0.00, R:0.25, A:0.00
WESA_S005_N6S_MLready.mat       Total: 1220
W:0.10, N1:0.26, N2:0.39, N3:0.00, N4:0.00, R:0.25, A:0.00
WESA_S006_N6S_MLready.mat       Total: 1255
W:0.21, N1:0.14, N2:0.45, N3:0.01, N4:0.00, R:0.18, A:0.00
WESA_S008_N4S_MLready.mat       Total: 1266
W:0.15, N1:0.20, N2:0.36, N3:0.14, N4:0.00, R:0.14, A:0.00
WESA_S043_N2S_MLready.mat       Total: 1500
W:0.15, N1:0.17, N2:0.39, N3:0.09, N4:0.00, R:0.20, A:0.00
WESA_S011_N7S_MLready.mat       Total: 1217
W:0.23, N1:0.12, N2:0.48, N3:0.03, N4:0.00, R:0.14, A:0.00
WESA_S042_N1S_MLready.mat       Total: 1640
W:0.05, N1:0.16, N2:0.49, N3:0.08, N4:0.00, R:0.21, A:0.00
WESA_S021_N1S_MLready.mat       Total: 1754
W:0.26, N1:0.16, N2:0.37, N3:0.04, N4:0.00, R:0.17, A:0.00
WESA_S005_N1S_MLready.mat       Total: 1337
W:0.13, N1:0.17, N2:0.43, N3:0.02, N4:0.00, R:0.25, A:0.00
WESA_S016_N1S_MLready.mat       Total: 1125
W:0.12, N1:0.08, N2:0.52, N3:0.16, N4:0.00, R:0.13, A:0.00
WESA_S040_N2S_MLready.mat       Total: 1527
W:0.19, N1:0.12, N2:0.27, N3:0.17, N4:0.00, R:0.25, A:0.00
WESA_S040_N1S_MLready.mat       Total: 1386
W:0.13, N1:0.19, N2:0.26, N3:0.14, N4:0.00, R:0.28, A:0.00
WESA_S004_N5S_MLready.mat       Total: 1327
W:0.09, N1:0.07, N2:0.31, N3:0.30, N4:0.00, R:0.23, A:0.00
WESA_S016_N10S_MLready.mat      Total: 1192
W:0.11, N1:0.11, N2:0.43, N3:0.16, N4:0.00, R:0.19, A:0.00
WESA_S004_N14S_MLready.mat      Total: 1401
W:0.10, N1:0.04, N2:0.32, N3:0.31, N4:0.00, R:0.23, A:0.00
WESA_S015_N4S_MLready.mat       Total: 1373
W:0.24, N1:0.14, N2:0.37, N3:0.09, N4:0.00, R:0.16, A:0.00
WESA_S008_N14S_MLready.mat      Total: 1342
W:0.15, N1:0.21, N2:0.35, N3:0.10, N4:0.00, R:0.17, A:0.00
WESA_S027_N1S_MLready.mat       Total: 991
W:0.16, N1:0.08, N2:0.45, N3:0.17, N4:0.00, R:0.14, A:0.00
WESA_S004_N1S_MLready.mat       Total: 1362
W:0.15, N1:0.12, N2:0.27, N3:0.32, N4:0.00, R:0.13, A:0.00
WESA_S037_N1S_MLready.mat       Total: 1549
W:0.13, N1:0.09, N2:0.35, N3:0.26, N4:0.00, R:0.17, A:0.00
WESA_S008_N7S_MLready.mat       Total: 1622
W:0.16, N1:0.10, N2:0.38, N3:0.17, N4:0.00, R:0.20, A:0.00
WESA_S041_N2S_MLready.mat       Total: 1555
W:0.07, N1:0.11, N2:0.31, N3:0.30, N4:0.00, R:0.20, A:0.00
WESA_S016_N09S_MLready.mat      Total: 1263
W:0.09, N1:0.11, N2:0.51, N3:0.15, N4:0.00, R:0.14, A:0.00
WESA_S011_N3S_MLready.mat       Total: 1206
W:0.10, N1:0.15, N2:0.56, N3:0.06, N4:0.00, R:0.13, A:0.00
WESA_S043_N1S_MLready.mat       Total: 1469
W:0.16, N1:0.14, N2:0.37, N3:0.11, N4:0.00, R:0.22, A:0.00
WESA_S029_N1S_MLready.mat       Total: 1563
W:0.12, N1:0.13, N2:0.34, N3:0.10, N4:0.00, R:0.30, A:0.00
WESA_S015_N1S_MLready.mat       Total: 1641
W:0.25, N1:0.11, N2:0.35, N3:0.12, N4:0.00, R:0.17, A:0.00
WESA_S015_N2S_MLready.mat       Total: 1293
W:0.17, N1:0.13, N2:0.47, N3:0.10, N4:0.00, R:0.13, A:0.00
WESA_S006_N4S_MLready.mat       Total: 1513
W:0.10, N1:0.09, N2:0.51, N3:0.03, N4:0.00, R:0.28, A:0.00
WESA_S042_N2S_MLready.mat       Total: 1559
W:0.08, N1:0.13, N2:0.45, N3:0.13, N4:0.00, R:0.21, A:0.00
WESA_S006_N13S_MLready.mat      Total: 1293
W:0.13, N1:0.14, N2:0.46, N3:0.01, N4:0.00, R:0.26, A:0.00
WESA_S011_N4S_MLready.mat       Total: 1355
W:0.14, N1:0.08, N2:0.48, N3:0.09, N4:0.00, R:0.21, A:0.00
WESA_S005_N10S_MLready.mat      Total: 1427
W:0.09, N1:0.13, N2:0.45, N3:0.01, N4:0.00, R:0.32, A:0.00
WESA_S016_N5S_MLready.mat       Total: 1105
W:0.08, N1:0.11, N2:0.60, N3:0.09, N4:0.00, R:0.12, A:0.00
WESA_S005_N5S_MLready.mat       Total: 1408
W:0.18, N1:0.09, N2:0.38, N3:0.12, N4:0.00, R:0.22, A:0.00
WESA_S015_N14S_MLready.mat      Total: 1510
W:0.18, N1:0.07, N2:0.45, N3:0.18, N4:0.00, R:0.12, A:0.00
WESA_S008_N3S_MLready.mat       Total: 1078
W:0.16, N1:0.19, N2:0.36, N3:0.18, N4:0.00, R:0.11, A:0.00
WESA_S032_N1S_MLready.mat       Total: 1218
W:0.05, N1:0.08, N2:0.39, N3:0.28, N4:0.00, R:0.20, A:0.00
WESA_S016_N13S_MLready.mat      Total: 1229
W:0.16, N1:0.06, N2:0.38, N3:0.24, N4:0.00, R:0.15, A:0.00
WESA_S032_N2S_MLready.mat       Total: 1195
W:0.06, N1:0.08, N2:0.36, N3:0.25, N4:0.00, R:0.25, A:0.00
WESA_S005_N12S_MLready.mat      Total: 1260
W:0.09, N1:0.14, N2:0.48, N3:0.00, N4:0.00, R:0.29, A:0.00
WESA_S011_N12S_MLready.mat      Total: 1327
W:0.11, N1:0.15, N2:0.49, N3:0.04, N4:0.00, R:0.21, A:0.00
WESA_S006_N2S_MLready.mat       Total: 1231
W:0.14, N1:0.20, N2:0.46, N3:0.01, N4:0.00, R:0.18, A:0.00
WESA_S008_N10S_MLready.mat      Total: 1231
W:0.16, N1:0.14, N2:0.34, N3:0.11, N4:0.00, R:0.24, A:0.00
WESA_S015_N06S_MLready.mat      Total: 1276
W:0.14, N1:0.12, N2:0.40, N3:0.19, N4:0.00, R:0.15, A:0.00
WESA_S027_N2S_MLready.mat       Total: 1139
W:0.17, N1:0.16, N2:0.50, N3:0.04, N4:0.00, R:0.13, A:0.00
WESA_S004_N8S_MLready.mat       Total: 1416
W:0.09, N1:0.09, N2:0.36, N3:0.25, N4:0.00, R:0.20, A:0.00
WESA_S037_N2S_MLready.mat       Total: 1550
W:0.10, N1:0.08, N2:0.43, N3:0.22, N4:0.00, R:0.16, A:0.00
WESA_S008_N1S_MLready.mat       Total: 1478
W:0.16, N1:0.18, N2:0.40, N3:0.11, N4:0.00, R:0.16, A:0.00
WESA_S041_N1S_MLready.mat       Total: 1609
W:0.08, N1:0.09, N2:0.32, N3:0.25, N4:0.00, R:0.26, A:0.00
WESA_S015_N9S_MLready.mat       Total: 1351
W:0.13, N1:0.11, N2:0.38, N3:0.26, N4:0.00, R:0.12, A:0.00
WESA_S021_N2S_MLready.mat       Total: 1614
W:0.27, N1:0.17, N2:0.45, N3:0.03, N4:0.00, R:0.08, A:0.00
WESA_S004_N3S_MLready.mat       Total: 1260
W:0.09, N1:0.05, N2:0.32, N3:0.31, N4:0.00, R:0.23, A:0.00
WESA_S029_N2S_MLready.mat       Total: 1490
W:0.11, N1:0.13, N2:0.41, N3:0.11, N4:0.00, R:0.23, A:0.00
