# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import os
import sys
import matplotlib.pyplot as plt
root_dir = os.path.abspath(os.path.join(os.path.dirname('__file__'), '..'))
sys.path.insert(0, root_dir)
from sleeplearning.lib.evaluation import Evaluation

# %% [markdown]
# ## Sleep Loop Data

# %%
path = 'results/caro/train'
e = Evaluation(path)
# Out:
# model attention
# config: all
# runs: model_best.pth.tar

# %%
e.cm()

# %% [markdown]
# This cell displays the confusion matrix on the evaluation data.

# %%
e.table()

# %% [markdown]
# This cell displays the per-file accuracy table.
# The class distribution is probably helpful for reasoning about the large difference in accuracy
# in the evaluation files. N12 clearly has the advantage of containing few of the difficult N3s.
#
# WESA_S005_N12S
# class distribution: {'WAKE': 109, 'N1': 174, 'N2': 608, 'N3': 4, 'REM': 364}
#
# WESA_S005_N1S
# class distribution: {'WAKE': 174, 'N1': 227, 'N2': 573, 'N3': 26, 'N4': 3, 'REM': 333}
#
# WESA_S005_N5S
# class distribution: {'WAKE': 260, 'N1': 130, 'N2': 534, 'N3': 171, 'REM': 312}

# %% [markdown]
# ## Sleep-EDF Data

# %% [markdown]
# We used the cassette data from the extended sleep-EDF dataset: https://physionet.org/physiobank/database/sleep-edfx/#sleep-cassette-study-and-data

# %%
path = 'results/sleepedf/train'
e = Evaluation(path)
# Out:
# model attention
# config: all
# runs: model_best.pth.tar

# %%
e.cm()

# %% [markdown]
# This cell displays the confusion matrix on the evaluation data.

# %%
e.table()

# %% [markdown]
# This cell displays the per-file accuracy table.
#
# SC4051E0-PSG
# class distribution: {'WAKE': 208, 'N1': 44, 'N2': 217, 'N3': 135, 'REM': 68}
#
# SC4121E0-PSG
# class distribution: {'WAKE': 176, 'N1': 48, 'N2': 463, 'N3': 107, 'REM': 258}
#
# SC4162E0-PSG
# class distribution: {'WAKE': 179, 'N1': 42, 'N2': 459, 'N3': 128, 'REM': 195}
